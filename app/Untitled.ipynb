# %%
import pandas as pd

# %%
import draft
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 import draft
#
# File ~/dev/projects/fantasy_bball/app/draft.py:7
#       3 import logging
#       5 import pandas as pd
# ----> 7 from app.exceptions import DraftPickleException, NoTransactionFileExists
#       9 log = logging.getLogger(__name__)
#      11 num_teams = 10
#
# File ~/dev/projects/fantasy_bball/app/app.py:9
#       6 from flask import Flask, render_template, request, flash, redirect, url_for
#       7 from flask.logging import default_handler
# ----> 9 from app.draft import get_data, compute_value, get_pickled_df, initialize_draft, league_teams, transaction, \
#      10     calculate_updated_values, replay_tranactions, calculate_current_team_values, calculate_team_spending, \
#      11     count_drafted_players, dollar_player_average_remaining
# ...

# %%
projections_path = '/Users/jjcaine/Downloads/rotowire-projections.xlsx'

# %%
df = pd.read_excel(projections_path)

# %%
df
# Out:
#            Unnamed: 0   Unnamed: 1 Unnamed: 2   Unnamed: 3 Projected Stats  \
# 0                Name         Team        Pos  Eligibility              GP
# 1        Adama Sanogo  Connecticut          C       Junior              34
# 2      Brandon Slater    Villanova          G       Senior              37
# 3      Posh Alexander   St. John's          G       Junior              32
# 4       Caleb Daniels    Villanova          G       Senior              37
# ..                ...          ...        ...          ...             ...
# 75    Stevie Mitchell    Marquette          G    Sophomore              32
# 76        Corey Floyd   Providence          G     Freshman              32
# 77       Ryan Mutombo   Georgetown          C    Sophomore              32
# 78       Mason Miller    Creighton          F     Freshman              32
# 79  Chris Arcidiacono    Villanova          G       Senior              37
#
# ...
